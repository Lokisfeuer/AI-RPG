# %% [markdown]
# Go to where?

# %%
import random

import random

def go_to(name):
    variations = [
        "I go to the market",
        "I head to the market",
        "I visit the market",
        "I'm off to the market",
        "I'm going to the market",
        "I walk to the market",
        "I journey to the market",
        "I make my way to the market",
        "I proceed to the market",
        "I set off for the market",
        "I move towards the market",
        "I take a trip to the market",
        "I travel to the market",
        "I venture to the market",
        "I stroll to the market",
        "I am on my way to the market",
        "I advance to the market",
        "I navigate to the market",
        "I march to the market",
        "I proceed to the market",
        "I am en route to the market",
        "I'm headed to the market",
        "I make my way to the market",
        "I'm on my way to the market",
        "I journey to the market",
        "I'm about to go to the market",
        "I set out for the market",
        "I'm stepping into the market",
        "I'm entering the market",
        "I prepare to go to the market",
        "I start for the market",
        "I'm making my way to the market",
        "I'm on my way to the market",
        "I proceed to the market",
        "I'm heading to the market",
        "I'm making a trip to the market",
        "I depart for the market",
        "I'm moving to the market",
        "I'm on the path to the market",
        "I'm taking a journey to the market",
        "I'm traveling to the market",
        "I'm setting off to the market",
        "I'm walking to the market",
        "I'm venturing to the market",
        "I'm strolling to the market",
        "I'm proceeding to the market",
        "I'm marching to the market",
        "I'm advancing to the market",
        "I'm navigating to the market",
        "I'm en route to the market",
        "I'm about to head to the market",
        "I'm making my way to the market",
        "I'm preparing to go to the market",
        "I'm starting for the market",
        "I'm departing for the market",
        "I'm moving towards the market",
        "I'm setting out for the market",
        "I'm stepping into the market",
        "I'm entering the market",
        "I'm on my way to the market",
        "I'm heading to the market",
        "I'm making a trip to the market",
        "I'm journeying to the market",
        "I'm traveling to the market",
        "I'm venturing to the market",
        "I'm strolling towards the market",
        "I'm proceeding to the market",
        "I'm marching towards the market",
        "I'm advancing towards the market",
        "I'm navigating towards the market",
        "I'm en route to the market",
        "I'm about to set off to the market",
        "I'm making my way towards the market",
        "I'm preparing to go to the market",
        "I'm starting to the market",
        "I'm departing to the market",
        "I'm moving to the market",
        "I'm stepping towards the market",
        "I'm entering the market",
        "I'm on the way to the market",
        "I'm heading towards the market",
        "I'm making a trip towards the market",
        "I'm journeying towards the market",
        "I'm traveling towards the market",
        "I'm venturing towards the market",
        "I'm strolling to the market",
        "I'm proceeding towards the market",
        "I'm marching to the market",
        "I'm advancing to the market",
        "I'm navigating to the market",
        "I'm en route to the market",
        "I'm about to walk to the market",
        "I'm making my way to the market",
        "I'm preparing to head to the market",
        "I'm starting towards the market",
        "I'm departing towards the market",
        "I'm moving towards the market",
        "I'm stepping to the market",
        "I'm entering the market",
        "I'm on the path to the market",
        "I'm heading to the market",
        "I'm making a trip to the market",
        "I'm journeying to the market",
        "I'm traveling to the market",
        "I'm venturing to the market",
        "I'm strolling to the market",
        "I'm proceeding to the market",
        "I'm marching towards the market",
        "I'm advancing towards the market",
        "I'm navigating towards the market",
        "I'm en route to the market",
        "I'm about to journey to the market",
        "I'm making my way to the market",
        "I'm preparing to travel to the market",
        "I'm starting to the market",
        "I'm departing to the market",
        "I'm moving to the market",
        "I'm stepping towards the market",
        "I'm entering the market",
        "I'm on the way to the market",
        "I'm heading towards the market",
        "I'm making a trip towards the market",
        "I'm journeying towards the market",
        "I'm traveling towards the market",
        "I'm venturing towards the market"
    ]
    go = random.choice(variations)
    go = go.replace('market', name)
    return go


locations = [
    "Park",
    "Beach",
    "Library",
    "Museum",
    "Restaurant",
    "Cafe",
    "Movie theater",
    "Shopping mall",
    "Gym",
    "School",
    "Office",
    "Zoo",
    "Concert hall",
    "Art gallery",
    "Stadium",
    "Hospital",
    "Farm",
    "Farm market",
    "Amusement park",
    "Spa",
    "Mountain",
    "Lake",
    "River",
    "Forest",
    "Jungle",
    "Desert",
    "Countryside",
    "City",
    "Suburb",
    "Village",
    "Town",
    "Island",
    "Skyscraper",
    "Cinema",
    "Bookstore",
    "Factory",
    "Workshop",
    "Studio",
    "Garden",
    "Orchard",
    "Vineyard",
    "Cemetery",
    "Castle",
    "Historical site",
    "Cave",
    "Lighthouse",
    "Waterfall",
    "Cruise ship",
    "Train station",
    "Airport",
    "Space station",
    "Underground",
    "Planetarium",
    "Carnival",
    "Circus",
    "Wildlife sanctuary",
    "Aquarium",
    "Botanical garden",
    "Coffee shop",
    "Tea house",
    "Ice cream parlor",
    "Bakery",
    "Farmers' market",
    "Campground",
    "Campsite",
    "Ski resort",
    "Beach resort",
    "Safari park",
    "Sculpture park",
    "University",
    "College",
    "Kindergarten",
    "Daycare",
    "Factory",
    "Lab",
    "Radio station",
    "Television studio",
    "Office building",
    "Observatory",
    "Underwater cave",
    "Haunted house",
    "Winery",
    "Microbrewery",
    "Planet",
    "Moon",
    "Sun",
    "Jupiter",
    "Forest",
    "Cabin",
    "Rainforest",
    "Jungle",
    "Wetland",
    "Volcano"
]


data = []
for _ in range(10000):
    locs = random.sample(locations, random.randint(2, 20))
    loc = random.choice(locs)
    txt = f''
    for i in locs:
        txt += f'{locs.index(i)+1}. {i}\n'
    txt += f'\n{go_to(loc)}'
    data.append([locs.index(loc)+1, txt])
    bad_txt = ''
    locs.remove(loc)
    for i in locs:
        bad_txt += f'{locs.index(i)+1}. {i}\n'
    bad_txt += f'\n{go_to(loc)}'
    data.append([0, bad_txt])

df = pd.DataFrame(np.array(data), columns=['Key', 'Value'])
df.to_csv('data_go_to_where.csv', index=False)
print("DataFrame saved as 'data.csv'")

# %% [markdown]
# Secrets found?

# %%
import os

import openai
import pandas as pd
import numpy as np

secrets = [
    "The local barkeeper secretly runs a round of poker in a backroom.",
    "A group of children claims to have seen strange lights in the forest at night.",
    "The town's blacksmith has been receiving mysterious orders for unusual weapons.",
    "The mayor's daughter has been sneaking out at night, rumored to be involved in a secret society.",
    "The innkeeper has been acting nervously and locking the cellar door more frequently.",
    "A traveler in the tavern tells tales of a haunted mansion on the outskirts of town.",
    "A local herbalist has been seen gathering rare and exotic plants from a hidden grove.",
    "A message written in code has been found pinned to a notice board.",
    "A beggar in the alleyway possesses an ornate key with an unknown purpose.",
    "The town's well has started producing water that tastes strangely sweet.",
    "A minstrel sings a ballad about a cursed amulet rumored to grant great power.",
    "An abandoned cart outside town holds crates of unusual gemstones.",
    "A local historian mentions a hidden tunnel system beneath the town's market square.",
    "A mysterious old woman offers to read players' fortunes, revealing cryptic predictions.",
    "A reclusive artist has been painting portraits that appear to age unnaturally.",
    "A street urchin claims to have seen shadowy figures meeting in the graveyard.",
    "A secret room behind a bookshelf in the library holds forbidden texts.",
    "A series of anonymous letters warn of an impending disaster at the town's festival.",
    "The captain of the guard has a scar that matches the description of a legendary warrior's mark.",
    "A local fisherman's net snags an ancient map detailing the location of a hidden treasure.",
    "A merchant sells peculiar items sourced from an otherworldly realm.",
    "A faded diary found in an attic hints at a long-lost family heirloom.",
    "A traveling circus has arrived with performers who appear to have magical abilities.",
    "A street vendor peddles a deck of cards that seem to predict future events.",
    "The town's clock tower chimes at unexpected intervals, echoing an ancient code.",
    "A rival adventuring party has been asking about the same local legends and mysteries.",
    "An astronomer notices a new constellation in the sky, rumored to hold a cosmic secret.",
    "A hidden compartment under a shopkeeper's counter conceals a stash of contraband.",
    "A local beekeeper's honey is said to have strange effects on those who consume it.",
    "A tavern's mirror reflects images of alternate realities and divergent paths.",
    "A beggar claims to have seen a ghostly figure wandering the outskirts of town at night.",
    "The town's apothecary possesses a collection of rare and potent ingredients.",
    "A rumor circulates about a doorway that leads to a pocket dimension of endless riches.",
    "An old tombstone in the cemetery has an inscription written in a forgotten language.",
    "The local guard captain wears an unusual pendant that reacts to nearby magical energy.",
    "A fortune teller's crystal ball reveals glimpses of a lost civilization's history.",
    "A peculiar bird is said to sing a song that can only be heard by those in need.",
    "The sound of faint music leads the party to a hidden grove where fairies gather.",
    "An old seafarer recounts tales of a cursed ship that still sails the seas.",
    "A local sculptor has been crafting lifelike statues that eerily resemble missing townsfolk.",
    "A broken sword hilt found in a cave hints at a legendary blade's hidden resting place.",
    "A hidden alcove in the chapel contains ancient manuscripts detailing forgotten rituals.",
    "A farmer's scarecrow appears to move on its own during the night.",
    "A mirror in an abandoned manor reflects a room that no longer exists.",
    "A collection of rare coins hints at an uncharted island where more treasure lies.",
    "A petrified forest is rumored to contain a grove where time flows differently.",
    "A wandering bard sings of a hidden waterfall that grants wishes to those who find it.",
    "An old sailor's map marks the location of a sunken city beneath treacherous waters.",
    "The party encounters a traveling circus that showcases creatures from distant realms.",
    "A missing heirloom leads to an underground cavern filled with luminescent fungi.",
    "A hermit living in the mountains possesses knowledge of a forgotten prophecy.",
    "The town's baker has a recipe for a bread that is said to grant visions.",
    "An abandoned mine is rumored to hold a gateway to the elemental plane of earth.",
    "A local beggar has a pet rat that seems unnaturally intelligent.",
    "A peculiar plant blooms only under the light of a full moon, and its nectar has strange effects.",
    "The village blacksmith is known to craft weapons using meteorite iron.",
    "A local historian claims to possess a map leading to an ancient library hidden in the desert.",
    "A hidden grotto in the forest contains an altar dedicated to an obscure deity.",
    "A wandering storyteller hints at a magic mirror that can show the viewer's true desires.",
    "Rumors swirl about a traveling merchant whose caravan is said to be a front for smugglers.",
    "A strange illness has struck the town, and rumors point to a cursed well as the source.",
    "A local guide offers to lead the party to a mystical glade rumored to heal any ailment.",
    "An old druid warns of an impending natural disaster and pleads for assistance.",
    "A map found in an old library suggests the existence of a hidden underwater city.",
    "A broken clock tower in the town center is rumored to start ticking at midnight.",
    "An eccentric inventor claims to have created a device that can communicate with spirits.",
    "A rare blue rose is said to grant its possessor the ability to speak to animals.",
    "Local miners have reported strange, musical echoes in the depths of the mines.",
    "A sculptor creates statues with eyes that seem to follow those who gaze upon them.",
    "A fisherman tells tales of a colossal fish that can bestow the gift of underwater breathing.",
    "A hidden garden is rumored to grant immortality to those who can find it.",
    "A traveling merchant carries a unique deck of cards that foretells the future.",
    "A series of crop circles has appeared in the fields, sparking rumors of extraterrestrial visitors.",
    "A local sage claims to have deciphered a prophecy that points to the rise of a chosen hero.",
    "An abandoned lighthouse is said to guide lost souls to the afterlife on stormy nights.",
    "A local guide offers to lead the party to a mystical glade rumored to heal any ailment.",
    "A curious constellation in the sky is believed to reveal the location of hidden treasures.",
    "A wandering bard sings of a sword that can only be wielded by a true hero.",
    "A hidden library contains books written in a language that only the pure of heart can read.",
    "A shipwreck on the coast is rumored to hold a cursed artifact with dangerous powers.",
    "A reclusive scholar studies the behavior of a flock of birds that seem to follow him.",
    "A traveling circus promises a glimpse into the future through a crystal ball.",
    "A series of cryptic symbols appear in the town's cobblestone streets during the night.",
    "An ancient tree is said to grant visions to those who sleep beneath its branches.",
    "An old alchemist seeks rare ingredients for a potion that can transmute base metal into gold.",
    "A secluded waterfall is rumored to be a portal to the realm of the fey.",
    "A local beekeeper claims that honey harvested during a lunar eclipse has magical properties.",
    "A stone tablet found in a hidden cave depicts a map to an underground labyrinth.",
    "A masked vigilante is rumored to patrol the streets at night, protecting the innocent.",
    "An old fortune teller offers to read the party's fate using a deck of enchanted tarot cards.",
    "A sunken shipwreck is said to hold a cursed treasure chest guarded by restless spirits.",
    "A scholar believes that a hidden star chart could reveal the location of an ancient artifact.",
    "A beggar whispers of a beguiling melody that can lure those who hear it into the woods.",
    "A hidden glade is rumored to be the home of a reclusive oracle with uncanny foresight.",
    "A local winemaker crafts a special vintage that can reveal hidden truths to those who drink it.",
    "A crumbling statue in the town square bears an uncanny resemblance to a missing noble.",
    "A mysterious masked ball is rumored to be held annually in a forgotten manor.",
    "A shepherd claims to have witnessed a meteor crash into the mountains, leaving behind a crater.",
    "A series of bizarre dreams plague the townsfolk, all of whom report seeing a shadowy figure.",
    "An old treasure map hints at a series of hidden caches that form a larger, intricate pattern.",
    "A traveling puppeteer's show seems to contain coded messages for those who can decipher them.",
    "A local wise woman offers to perform a ritual that can reveal hidden truths to those who partake.",
    "An abandoned laboratory contains notes and sketches detailing experiments with the fabric of reality."
]


falses1 = []
falses2 = []
trues1 = []
trues2 = []
for i in secrets:
    print(f'Starting with round {i}/30')  # TODO use index
    response = openai.Completion.create(
        model="text-davinci-003",
        prompt=f'Describe a room thereby dropping a hint on this secret:\n"{i}"',
        max_tokens=50
    )
    response_text = response.choices[0].text.strip()
    trues1.append(f'Secret: "{i}"\nResponse: "{response_text}"')
    response = openai.Completion.create(
        model="text-davinci-003",
        prompt=f'Talk to somebody thereby dropping a hint on this secret:\n"{i}"',
        max_tokens=50
    )
    response_text = response.choices[0].text.strip()
    trues2.append(f'Secret: "{i}"\nResponse: "{response_text}"')

    response = openai.Completion.create(
        model="text-davinci-003",
        prompt=f'Describe a room in detail.',
        max_tokens=50
    )
    response_text = response.choices[0].text.strip()
    falses1.append(f'Secret: "{i}"\nResponse: "{response_text}"')
    response = openai.Completion.create(
        model="text-davinci-003",
        prompt=f'Talk to somebody about something you know quite well.',
        max_tokens=50
    )
    response_text = response.choices[0].text.strip()
    falses2.append(f'Secret: "{i}"\nResponse: "{response_text}"')


data = []
for i in range(len(secrets)):
    data.append([True, trues1[i]])
    data.append([True, trues2[i]])
    data.append([False, falses1[i]])
    data.append([False, falses2[i]])
df = pd.DataFrame(np.array(data), columns=['Key', 'Value'])
df.to_csv('data_secrets_found.csv', index=False)
print("DataFrame saved as 'data.csv'")

# %% [markdown]
# Get relevant object

# %%
import numpy as np
import pandas as pd
import openai
import random
import json

# Set your OpenAI API key here
openai.api_key = os.getenv("OPENAI_API_KEY")

# List of common first names
first_names = [
    "Emma", "Olivia", "Ava", "Isabella", "Sophia",
    "Mia", "Charlotte", "Amelia", "Harper", "Evelyn",
    "Abigail", "Emily", "Elizabeth", "Sofia", "Avery",
    "Ella", "Scarlett", "Grace", "Chloe", "Victoria",
    "Riley", "Aria", "Lily", "Hannah", "Layla",
    "Brooklyn", "Zoe", "Nora", "Leah", "Savannah",
    "Audrey", "Claire", "Ariana", "Penelope", "Maya",
    "Stella", "Mila", "Gabriella", "Aurora", "Paisley",
    "Skylar", "Bella", "Nova", "Emilia", "Luna",
    "Ellie", "Zara", "Hazel", "Natalie", "Lillian",
    "Liam", "Noah", "Ethan", "Oliver", "Aiden",
    "Caleb", "Mason", "Elijah", "James", "Benjamin",
    "Lucas", "Alexander", "William", "Henry", "Daniel",
    "Michael", "Matthew", "Logan", "Jackson", "David",
    "Joseph", "Samuel", "Andrew", "Gabriel", "Christopher",
    "John", "Anthony", "Dylan", "Isaac", "Nicholas",
    "Jonathan", "Ryan", "Nathan", "Adam", "Thomas",
    "Joshua", "Evan", "Landon", "Connor", "Christian",
    "Aaron", "Tyler", "Cameron", "Wyatt", "Owen",
    "Jack", "Hunter", "Eli", "Jordan", "Levi"
]


# Create a dictionary to store responses for each name
name_responses = {name: [] for name in first_names}
room_responses = []

# Send requests to OpenAI and save answers
for _ in range(1000):
    print(f'Starting with round {_+1}/30')
    name = random.choice(first_names)
    response = openai.Completion.create(
        model="text-davinci-003",
        prompt=f"Ask something about a person called {name} in the room you are in.\n\n",
        max_tokens=50
    )
    response_text = response.choices[0].text.strip()
    name_responses[name].append(response_text)

    response = openai.Completion.create(
        model="text-davinci-003",
        prompt="Ask something about the room you are in.\n\n",
        max_tokens=50
    )
    response_text = response.choices[0].text.strip()
    room_responses.append(response_text)

print(f'name responses: {name_responses}')
print(f'room responses: {room_responses}')
with open('quicksave.json', 'w') as f:
    json.dump({'name_responses': name_responses, 'room_responses': room_responses}, f)

all_data = []
to_dataframe = []
for _ in range(5000):
    entry = '1. Room'
    x = random.randint(2, 5)
    names = random.sample(first_names, x)
    data = {'room': random.choice(room_responses)}
    for i in range(x):
        entry += f'\n{i+2}. {names[i]}'
        data[names[i]] = random.choice(name_responses[names[i]])
    entry += '\n\n'
    for idx, response in enumerate(list(data.values())):
        all_data.append({idx: entry + response})
        to_dataframe.append([idx, entry + response])

df = pd.DataFrame(np.array(to_dataframe), columns=['Key', 'Value'])

# Save the DataFrame as a CSV file
df.to_csv('data.csv', index=False)

print("DataFrame saved as 'data.csv'")

# %%
import openai
import numpy as np
import pandas as pd
import os

openai.api_key = os.getenv("openai.api_key")

def ask_ai(x, y):  # get nr of answers from a prompt. Prompt should end with '\n\n1.'.
    response = openai.Completion.create(model="text-davinci-003", prompt=x, temperature=1,
                                        max_tokens=20 * y)
    response = '1.' + response['choices'][0]['text'] + '\n'
    li = []
    for i in range(y):
        pos = response.find(str(i + 1))
        beg = pos + len(str(i + 1)) + 2
        end = response[beg:].find('\n')
        li.append(response[beg:beg + end])
    return li


info = 'Give me a question somebody might ask about the room they are in or about somebody they see in that room.'

verbatim = 'Give me an interesting sentence I might say to another person during a conversation. Do not use quotation marks.'

action = 'Tell me something I do when I am in a room. Speak in the first person and use "I". Write only a single short sentence. Say what I\'d do.'

attack = 'Tell me that you are attacking someone. Describe briefly how. Use just one sentence.'

location_change = 'I go to a nearby place.\nGive me a single variation of the prior sentence and use a different place every time. Include where you are going.\n'

prompts = [info, verbatim, action, attack, location_change]

n = 200

all_sentences = []
labels = []
for _ in range(5):
  for idx, i in enumerate(prompts):
      master_prompt = f'Prompt: "{i}"\nGive me {n} Possible answers to this prompt.\n\n1.'
      new_sentences = ask_ai(master_prompt, n)
      for j in new_sentences:
          if j not in all_sentences:
              all_sentences.append(j)
              '''
              one_hot = np.zeros(max)
              one_hot[idx] = 1
              '''
              labels.append(idx)

data = [all_sentences, labels]
data = np.array(data).transpose()

pd.DataFrame(data).to_csv(f"data_type.csv", index=False, header=['sentences', 'labels'])
print('saved to data_type.csv')
